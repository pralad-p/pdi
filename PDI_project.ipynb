# %%
import xml.etree.ElementTree as ET
tree = ET.parse('cddb_1000.xml')
root = tree.getroot()

for disc in root.findall('disc'):
    artist = disc.find('artist').text
    title = disc.find('dtitle').text
    category = disc.find('category').text
    tracks = disc.find('tracks').text
    print (artist)
# Out:
# Various
# NO RETURN
# ä¸­æ�‘é›…ä¿Š
# Emanuel
# åŠ‡å›£å››å­£
# luv lite massive
# Various Artists
# DMBQ
# 4 P.M.
# Various
# ¾î¸°ÀÌ Worship
# Rumania Montevideo
# pink floyd
# Modern Talking
# Keedy
# ????
# Various
# Carlos Santana
# Bill Evans
# Nature Destroyed
# PEARL JAM
# Dingdong Avanzado
# Frans Bauer
# 175R
# Various
# Day After Tomorrow
# V.A
# Jazz Signatures
# Bernadète Bidàude
# å±±å�£ç™¾æ�µ
# Spartak
# <V8.5e
# 2Pac
# å�‚æœ¬çœŸç¶¾
# Gazebo
# DJ Irish
# Sportfreunde Stiller
# Rennie Pilgrim presents
# Various
# Barbara Streisand
# Italo House
# DEUX
# V.A.
# Various
# Matsuka Phonics
# Kool Savas
# Robotika
# The Breeders
# Johnny Hallyday
# Phallus
# å±±å´Žã�¾ã�•ã‚ˆã�—
# Rolling Stones
# Ì¤ÃÎ
# äîëåðä ùì äâøåá
# Nakama1
# Various Artists
# éˆ´æœ¨ã�‚ã�¿
# Green Day
# çŸ¢æ²¢æ°¸å�‰
# Various
# ¼Ò¸®¿¤
# In Vanity We Trust
# Various Artists
# Savage
# Atmo Brtschitsch
# Del Amitri
# ¿©Çà_½ºÄÉÄ¡
# Diverse
# Nikos Hatzopoulos
# Perseguidos
# ¿ÀÁß±âÈ¹
# Various Artists
# ...

# %%
from fuzzywuzzy import fuzz
Str1 = "Shane Barnard, Psalms, folk "
Str2 = "Shane Barnard, Psalms, misc "
Ratio = fuzz.token_set_ratio(Str1.lower(),Str2.lower())
print(Ratio)
# Out:
# 89
